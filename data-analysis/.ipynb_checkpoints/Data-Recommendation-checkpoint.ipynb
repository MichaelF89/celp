# %% [markdown]
# # Analyze Data
#
# Korte data analyse voor het verkenne van de yelp data voor het verslag van week 1.

# %%
# Imports
import pandas as pd
import os
import json
import random
from IPython.display import display
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
"""
This file loads the data from the data directory and shows you how.
Feel free to change the contents of this file!
Do ensure these functions remain functional:
    - get_business(city, business_id)
    - get_reviews(city, business_id=None, user_id=None, n=10)
    - get_user(username)
"""

import os
import json
import random

DATA_DIR = "../data"


def load_cities():
    """
    Finds all cities (all directory names) in ./data
    Returns a list of city names
    """
    return os.listdir(DATA_DIR)


def load(cities, data_filename):
    """
    Given a list of city names,
        for each city extract all data from ./data/<city>/<data_filename>.json
    Returns a dictionary of the form:
        {
            <city1>: [<entry1>, <entry2>, ...],
            <city2>: [<entry1>, <entry2>, ...],
            ...
        }
    """
    data = {}
    for city in cities:
        city_data = []
        with open(f"{DATA_DIR}/{city}/{data_filename}.json", "r") as f:
            for line in f:
                city_data.append(json.loads(line))
        data[city] = city_data
    return data


def get_business(city, business_id):
    """
    Given a city name and a business id, return that business's data.
    Returns a dictionary of the form:
        {
            name:str,
            business_id:str,
            stars:str,
            ...
        }
    """
    for business in BUSINESSES[city]:
        if business["business_id"] == business_id:
            return business
    raise IndexError(f"invalid business_id {business_id}")


def get_reviews(city, business_id=None, user_id=None, n=10):
    """
    Given a city name and optionally a business id and/or auser id,
    return n reviews for that business/user combo in that city.
    Returns a dictionary of the form:
        {
            text:str,
            stars:str,
            ...
        }
    """
    def should_keep(review):
        if business_id and review["business_id"] != business_id:
            return False
        if user_id and review["user_id"] != user_id:
            return False
        return True

    reviews = REVIEWS[city]
    reviews = [review for review in reviews if should_keep(review)]
    return random.sample(reviews, min(n, len(reviews)))


def get_user(username):
    """
    Get a user by its username
    Returns a dictionary of the form:
        {
            user_id:str,
            name:str,
            ...
        }
    """
    for city, users in USERS.items():
        for user in users:
            if user["name"] == username:
                return user
    raise IndexError(f"invalid username {username}")


CITIES = load_cities()
USERS = load(CITIES, "user")
BUSINESSES = load(CITIES, "business")
REVIEWS = load(CITIES, "review")
TIPS = load(CITIES, "tip")
CHECKINS = load(CITIES, "checkin")

# %%
''' Schoonmaken BUSINESSES'''
#business = citymerge(BUSINESSES)
#business = business[business['is_open'] == 1 & business['categories'].notna()]
#business['categories'] = business['categories'].str.split(', ')
#print(business.latitude.mean(), business.longitude.mean())
# Out:
# ' Schoonmaken BUSINESSES'

# %%
# Functie om data van alle steden samen te voegen in 1 DataFrame
def citymerge(var):
    return pd.concat([pd.DataFrame(var[city]) for city in var]).reset_index()

# %%
# Creeer Utility Matrix en Mean Utility Matrix uit een variabele van data.py (REVIEWS, USERS, BUSINESSES, etc.)
def create_utility_matrix(var):
#     df = citymerge(var)
    df = var

    utility_matrix  = pd.pivot_table(df, index='business_id', columns='user_id', values='stars')

    mean_ultility_matrix = utility_matrix - utility_matrix.mean()
    
    return utility_matrix, mean_ultility_matrix
    
utility_matrix, mean_utility_matrix = create_utility_matrix(reviews)

# %%
# Creeer Similarity Matrix uit Mean Utility Matrix
def similarity(mum):
    return pd.DataFrame(cosine_similarity(mum.fillna(0)), index=mum.index, columns=mum.index).replace(0, np.nan)

similarity_matrix = similarity(mean_utility_matrix)

# %%
def select_neighborhood(similarity_matrix, utility_matrix, target_user, target_business):
    """selects all items with similarity > 0"""
    # Controleer of target_user en target_business wel in de matrix zijn te vinden.
    if (target_business in similarity_matrix.index) and (target_user in utility_matrix.columns):

        # Maak een boolean mask van bedrijven die de gebruiker beoordeeld heeft met een similarity hoger dan 0.
        SelectedBusinesses = (similarity_matrix[target_business].index.isin(utility_matrix[target_user].dropna().index)) & (similarity_matrix[target_business] > 0)
    
        # return de bedrijven met de similarity door gebruik te maken van de eerder gecreeerde boolean mask.
        return similarity_matrix[target_business][SelectedBusinesses].sort_values(ascending = False)
    
    # Bij waarden die niet gevonden kunnen worden geef None terug.
    else:
        return pd.Series()

# %time neighborhood = select_neighborhood(similarity_matrix, utility_matrix, 'e3fdrK1tMCwWLr76LFe-cA', 'ZTg8adZipR3QDoJmFZZqJw')
display(neighborhood)
# Out:
# Wall time: 4.99 ms
# business_id
# ZTg8adZipR3QDoJmFZZqJw    1.000000
# oZH3Ee7Yjk7u8B4Ed0oVOg    0.052780
# eigkQ_PuRON8Se265NqQDQ    0.050649
# r0DureDzsHpzs_VZem5k7g    0.046030
# 0VJ8tBxOpD2OxuioVjaAxA    0.038859
# 5MWWP4Kpmw0e8d2ib9G7Kg    0.031414
# EpJhRvkGDFE-GDPHM32klw    0.019380
# PzuyoHj3-VrYK7N8ZestNA    0.015228
# spjaRNFn9Lmh4petKBuf5g    0.011917
# 6tK-R3BQ-GiMxsCGtxpJyw    0.001078
# irwDkp2eMP2x-4MfunRt8g    0.000097
# Name: ZTg8adZipR3QDoJmFZZqJw, dtype: float64

# %%
def weighted_mean(neighborhood, utility_matrix, user_id):
    # Controleer of neighborhood wel een Series is en utility_matrix wel een DataFrame, anders return 0.
    if isinstance(neighborhood, pd.Series) and isinstance(utility_matrix, pd.DataFrame):
        # Als neighborhood of de utility_matrix leeg zijn return dan 0.
        if (neighborhood.empty) or (utility_matrix.empty):
            return 0
        
        # Controleer of user_id als kolom te vinden is, anders return 0.
        elif user_id in utility_matrix.columns:
    
            # Gebruik de bovenstaande formule om het gewogen gemiddelde voor de neighborhood te berekenen.
            return ((utility_matrix[user_id] * neighborhood).dropna().sum()) / (neighborhood.sum())

        else:
            return 0
    else:
        return 0
    
prediction = weighted_mean(neighborhood, utility_matrix, 'e3fdrK1tMCwWLr76LFe-cA')
print (prediction)
# Out:
# 3.9637712566801744

# %%
# Voorspel een score voor bedrijven en return deze als dict
def predictions(utility_matrix, similarity_matrix, user_id):
    predictdict = defaultdict()
    
    # Extract list of reviewed businesses to get new results
    review_list = utility_matrix[user_id][utility_matrix[user_id].notna()].index
    
    for business_id in similarity_matrix.index:
        if business_id in review_list:
            pass
        else:
            predictdict[business_id] = weighted_mean(select_neighborhood(similarity_matrix, utility_matrix, user_id, business_id), utility_matrix, user_id)
    
    return predictdict

# %%
# %time userpredict = predictions(utility_matrix, similarity_matrix, 'zyGHTM-BbeY7umYiVFRoSQ')
# Out:
# Wall time: 3.37 s

# %%
test = utility_matrix['e3fdrK1tMCwWLr76LFe-cA'][utility_matrix['e3fdrK1tMCwWLr76LFe-cA'].notna()].index

# %%
#userpredict
import operator
# sorted_userpredict = sorted(userpredict.items(), key=operator.itemgetter(1), reverse=True)

# %%
# sorted_userpredict

# %%
# businessdf = citymerge(BUSINESSES)

# %%
#businessdf
pserie = pd.Series(userpredict)

test = pserie[pserie != 0].sort_values(ascending=False)

test2 = businessdf[businessdf['business_id'].isin(test.index)]

test2  = test2.assign(prediction=test2['business_id'].map(userpredict)).sort_values('prediction', ascending=False)

test2['stars'] = test2['stars'].astype(str)

a =test2[test2['is_open'] == 1].head(10)[['business_id', 'stars', 'name', 'city', 'address']].to_dict(orient='records')

# %%
'-2XMn8phKIqizvss9PBLCw' in ibcf_predictions.keys()
# Out:
# True

# %%
CITY = 'westlake'
reviews = pd.read_json(DATA_DIR+'/'+CITY+'/review.json', lines=True)
businesses = pd.read_json(DATA_DIR+'/'+CITY+'/business.json', lines=True)
# display(pd.read_json(DATA_DIR+'/'+CITY+'/user.json', lines=True).head())
# reviews[reviews['user_id'] == 'apP3CApEq6-z59tRLwEBYA']['business_id']

def predictions_combiner(ibcf_predictions, cb_predictions, ibcf_weight=0.8, reviews=reviews, businesses=businesses):
    hybrid_predictions = {}
    cb_weight = 1 - ibcf_weight
    for business_id in cb_predictions:
        if business_id in ibcf_predictions:
            ibcf_prediction = ibcf_predictions[business_id]
            cb_prediction = cb_predictions[business_id]
            hybrid_predictions[business_id] = ibcf_prediction*ibcf_weight + cb_prediction*cb_weight
            if ibcf_prediction == 0:
                hybrid_predictions[business_id] = cb_prediction
            if cb_prediction == 0:
                hybrid_predictions[business_id] = ibcf_prediction
        else:
            hybrid_predictions[business_id] = cb_prediction
            
    return  dict(sorted(hybrid_predictions.items(), key=operator.itemgetter(1), reverse=True))
    
def content_based_recommender(user_id, businesses=businesses):
    predicted_ratings = {}
    category_dict = make_category_dict(user_id)
    for business_id in businesses['business_id']:
        predicted_ratings[business_id] = content_based_predictor(user_id, business_id, category_dict)
    return predicted_ratings
    
def content_based_predictor(user_id, business_id, category_dict, reviews=reviews, businesses=businesses):
    ratings = []
    categories = businesses[businesses['business_id'] == business_id]['categories'].str.split(', ')
    for x in categories:
        for category in x:
            if category in category_dict:
                ratings.append(category_dict[category])
    if len(ratings) == 0:
        return 0
    else:
        return sum(ratings)/len(ratings)
        
def make_category_dict(user_id, reviews=reviews, businesses=businesses):
    category_dict = {}
    user_reviews = reviews[reviews['user_id'] == user_id]
    business_ids = user_reviews['business_id']
    for business_id in business_ids:
        categories = businesses[businesses['business_id'] == business_id]['categories'].str.split(', ')
        stars = user_reviews[user_reviews['business_id'] == business_id]['stars'].values[0]
        for x in categories:
            for category in x:
                if category in category_dict:
                    category_dict[category].append(stars)
                else:
                    category_dict[category] = [stars]
    for category in category_dict:
        category_dict[category] = sum(category_dict[category])/len(category_dict[category])
    return category_dict

# %time cb_predictions = content_based_recommender('e3fdrK1tMCwWLr76LFe-cA')
# %time ibcf_predictions = predictions(utility_matrix, similarity_matrix, 'e3fdrK1tMCwWLr76LFe-cA')
# cb_predictions
# ibcf_predictions
# only_icbf = predictions_combiner(ibcf_predictions, cb_predictions)
all_predictions = predictions_combiner(ibcf_predictions, cb_predictions)
# Out:
# Wall time: 332 ms
# Wall time: 2.97 s

# %%
def select_items(predictions):
    pool = []
    average = sum(list(predictions.values())[0:10])/10
    while len(pool) < 10:
        average -= 0.1 * average
        for prediction in predictions:
            if predictions[prediction] > average:
                pool.append(prediction)
            else:
                break
    return random.sample(pool, k=max10)

select_items(all_predictions)
# Out:
# ['hSOT9HNTINzBVV5MbNBMVQ',
#  '7BIMKg5DAVi_vHNBd7pmiA',
#  'MgO_JJB7k_Szs1sjnGfpOA',
#  'JicFOJCipO_JeHzpjcmzCQ',
#  'HW7JPZBImm3tyEpDgGxKGQ',
#  'NGAUlZFlt8WPjWJqa_kfyQ',
#  'Gd5jcl9smnwASaFYmJX75A',
#  'tqvs47tAS6i2Z_IOlZbGsg',
#  '8x3rDQCKUJfnJSdsU_6Y3g',
#  'Nc8VF2ZbwSUIQ8w2CUJvQw']

# %%
all_predictions
# Out:
# {'lWCpbAnV232FjLo7FbHLkQ': 5.0,
#  'tqvs47tAS6i2Z_IOlZbGsg': 5.0,
#  'Gd5jcl9smnwASaFYmJX75A': 4.648648648648648,
#  'Cw0mtFh9u2_4SVXe8Tl1rw': 4.333333333333333,
#  'BUkk5nwestqU5uH04km_yg': 4.333333333333333,
#  '6tK-R3BQ-GiMxsCGtxpJyw': 4.333333333333333,
#  'QYPUE-U7bC4YOlSQDSGXLQ': 4.249550243713876,
#  'XaqWUocr0MlYVi5yusjk0Q': 4.142745944345377,
#  'NGAUlZFlt8WPjWJqa_kfyQ': 4.1110673933906705,
#  'HW7JPZBImm3tyEpDgGxKGQ': 4.106779118731299,
#  'j_oKMbKv4vlkyRxD9p1fKA': 4.066666666666666,
#  'nYvBZYg9rfqWFTYuxSVMdw': 4.064734561544528,
#  '-MsRvdPnuw6QuLn5Vxjruw': 4.0,
#  'i7lFu1-iadoXW5Hn-JWaeg': 4.0,
#  '9vsqbJgjUqQNJpHrSj6jKw': 4.0,
#  'iu3nhUGL69utOEyKzOIy3w': 4.0,
#  'zOdx4EdRSb2BM06hbq5Tww': 4.0,
#  'op0sZT-TNyeTMw0m3HUUDQ': 4.0,
#  'uro64fxfGuoUXF159W0n_w': 4.0,
#  'Na2HX930AMuPw5eKKy5iiQ': 4.0,
#  '5e5lFXdPWUZlAzHi-AUDYQ': 4.0,
#  'wAP6tV4HtTHPjVTPP0OBGw': 4.0,
#  'vWzfFvSxZCjSWPoVFn6idw': 4.0,
#  'pYad8gX0DTOGFDcF5p8dxw': 4.0,
#  'Gq9rNXqgV2qnTXy2GXGdtQ': 4.0,
#  'GCTVuBcDZZolh8ND4KSwWA': 4.0,
#  '8x3rDQCKUJfnJSdsU_6Y3g': 4.0,
#  '5w308TrL-7RQERpZmHSYow': 4.0,
#  'togjHtE_R6SUaOJnwAY_UA': 4.0,
#  'vpa1uygT6ZGeHkT53IxSRA': 4.0,
#  'Hib3S6clwTykOAY_T-_rnQ': 4.0,
#  'MgO_JJB7k_Szs1sjnGfpOA': 4.0,
#  'hSOT9HNTINzBVV5MbNBMVQ': 4.0,
#  'JicFOJCipO_JeHzpjcmzCQ': 4.0,
#  'U3tK4xqUdSCxWZNIAWpx0A': 4.0,
#  'yWAakMmtP-Hpojf3tuFV6A': 4.0,
#  '7BIMKg5DAVi_vHNBd7pmiA': 4.0,
#  'Nc8VF2ZbwSUIQ8w2CUJvQw': 4.0,
#  'a7u8nV2Le_73UrsrYAwCVQ': 4.0,
#  'U1DHIKY3eQWt-OqT7pO_eg': 3.988609431360189,
#  'rcoAajAVBBXsBNfgKYaH-w': 3.9801854536088506,
#  'MgMHirbN-QKk4NcncQ3X4w': 3.9333333333333336,
#  'dHgzFLkOZ2tmlMPVU4wqEw': 3.9252574002574003,
#  '7hIl2AOZl6Zfr2fAojpeRw': 3.9195993368869977,
#  '0J2QK4Hk8EvJKYGu65qH8w': 3.9163953161265317,
#  'l4XGh5ga8j3H9Iuagt-6HQ': 3.9067129445261948,
#  'zpCS2Gt8MOPiiIham-OBKw': 3.90421801570418,
#  'hTdV1_Xn1j6yhpIR7CgCJQ': 3.901954582521163,
#  'LhW7pWkVgu_bAMiRhO3Wow': 3.9,
#  'UT0FUBRmpnGHE1U4Jpegxw': 3.9,
#  'zcN7cJvxIXY7cDBjI86Ziw': 3.9,
#  'TU9YbBD7Y9r0ev8qDbpELA': 3.9,
#  'rubbDSAiD7wzzqNDmgsD4g': 3.9,
#  'TSOeMJIdmdnAOLLfI8hzZA': 3.887253151452984,
#  'vkD7xW81EgCSWwiTvxtVAw': 3.8844304096081075,
#  'eJF709RvGYjx57gO06loyg': 3.882932854829302,
#  'YmTD876xN9YFH6mIe8ZrtA': 3.8773758914534002,
#  'KSDl6yx-Kc60yyJHNvz7zg': 3.874617837883908,
#  'kdwL8bcqFKtYM3KFaB__IA': 3.8743243243243244,
#  '46KhEmhF3mn9ifWP67HpTA': 3.8743243243243244,
#  '4Dwgwamq4EyeZPtJMQT5qg': 3.8743243243243244,
#  'Scub4d_tTkdD7g7QxcaaGg': 3.8717717717717717,
#  'dkBOmWWYcRFhItVAr3HFiA': 3.867040501803356,
#  'kts54mVKhgMvU_qDsXCCpw': 3.861225171040733,
#  'CPTh8I6MQBv9yC8qIc5FkA': 3.8518777804972255,
#  'IXJ5sfKnsGu6drrFUceQ5Q': 3.849585280004574,
#  'kkNWzhSpAjxm0zIxol3IzQ': 3.848648648648649,
#  'RWnDNJ5OrUTPfv0yVuq_fg': 3.846855817377012,
#  '6Pe0dldgxAdxPI5yt3SLQw': 3.8179536679536685,
#  'SA4ZV8JInv9IkW7L8O7JlA': 3.813545814870578,
#  '6Nkdu1-hrsrlZO_fkaj1gw': 3.810496707732988,
#  'TaR8jFGD5OvHaY_ve7m4Rw': 3.80617119308201,
#  'G09kuZ7Z_4cdIv0MRwV_LA': 3.7859079138069904,
#  'UobSPAAzgt7HKmWoepi31A': 3.782882882882883,
#  'Vy3fKPH7oZB4nrrkjUuAuA': 3.781183760778291,
#  'EpJhRvkGDFE-GDPHM32klw': 3.7810810810810813,
#  'wmGJWlimnBK909IEgKVIIA': 3.7809702906612843,
#  'y_hf7TO6b6-VkxjhV9cqyA': 3.7714710090716372,
#  '6P-O4Tug5huPoA8NzbgPDw': 3.7701421545206997,
#  'yBPeUobSSaJQKaYYgiOKYA': 3.7677906117190845,
#  'AdXJ1hkcH3RRZ2xqBhtuTQ': 3.762800949204637,
#  'VdlbAvRYAqb8B4SIe8LhlA': 3.7576576576576577,
#  '1pz_bSQXV4od4d8H0znV7g': 3.75,
#  'UZBaD8BFVIuQ01YBST2DOA': 3.7331399696448604,
#  'CSKowRkeQl7QOOePLoaPeA': 3.7139820404495674,
#  'Ra5fI9BEAuWWaLJSfkiCiQ': 3.708893218173134,
#  'cz-JzFFiZVgSR83S-FBrGA': 3.69975474531546,
#  'lOyCHKj7mp9MiJ-iOEKFHA': 3.699125219480756,
#  'ki3lZMCg9EY3W4_F5l_98w': 3.6991252194807553,
#  '95Efv0xKoUsP5lvTnaeK5w': 3.6901755586935643,
#  '7dlCzYnXDaubTAfvgAX6sQ': 3.6901727624571903,
#  'O_vu446FgjhEC3w-gCJS-g': 3.6885488352337306,
#  '-ak1fx5L9cNjUE56as12MA': 3.6839413917386166,
#  'ELIINdJ7w8FcfcGqoGbPoA': 3.679407561745227,
#  'bRAQFWRxN4lh9WogWxLJ9g': 3.6747424400172504,
#  'EDzj2cVa1Wjk6IRsDfgQ-g': 3.6666666666666665,
#  'HJx0usnyVijOom2q73xGIA': 3.6578226296168648,
#  'kXRG_PEpz8G-IUkS1efdMA': 3.657489655719439,
#  'WUZEM2kfzYhGT3gv2rTOfg': 3.655621926657039,
#  'REfekXeUbPWGkgvlzSNbpw': 3.654362934362934,
#  '9MpWhQOYziJ38EB7MctxcA': 3.6532201457880493,
#  '8_9NeKvvJVaDZyhwchKM-w': 3.6451772088999266,
#  '0ZN2MfHyjNIkCx7qJvVhDg': 3.6325616666937544,
#  'qJkDbR5GCCjCafqc10A9iQ': 3.6315177042614644,
#  'rQd2dvzz-V4cjHbW9pf06g': 3.617422123543728,
#  'IhXZv1u4p2KHyxaVPw6lxQ': 3.6165228060215306,
#  'kWPCYYQZb6w6Eny2Cz0rnQ': 3.6,
#  'gwhETp-9hZo43B67cEos8g': 3.6,
#  'zuR-nKrXfVl4_WVP0n_AMg': 3.597492319743861,
#  'GJ-cTUQnp4Lk1neZi4P4gw': 3.589693832311185,
#  'jwlSQz--Xl_6eMUJfEy4ag': 3.5790837928204002,
#  'iytPyg_lc_cBb3id1oaDGA': 3.5718197592333256,
#  'SPb3oLIVZynmiS670Vo1kQ': 3.5707000230228587,
#  'K5iqS0JXnKFFujZHIWQsag': 3.566558297091854,
#  '3NuQdQQdLV9de4GODl_cUA': 3.557944731242812,
#  'Rvqprshh_M_Q-AGJNkpcyg': 3.546868296868297,
#  'vNPJbqYuJEFDPOLhoq3bFA': 3.530684561178298,
#  '5kCRty4p7tBwM9P7MAXgvA': 3.5271783561035606,
#  'He6gCZdGICRXw-G7IusxBA': 3.5263048993787014,
#  'mA9cKhzB6OGue-LOeTdqlw': 3.5257097652124187,
#  'VXyr1KyDiXc24WAwZ8tAmg': 3.5210243375617574,
#  'vfsbLhXGiXm8lqI12abrbQ': 3.5207499045543122,
#  'oBX1gy7oj6w6W3VocRQaGw': 3.5016020720430863,
#  'TUC1Nu3M2iB8RximXsx8HA': 3.5000000000000004,
#  '3-hEGiSGo2K0gyPzYeVASQ': 3.5,
#  'OiR6kP_mAD47vKU1WiPshg': 3.4982188248011297,
#  'm9Cme6bUPuZFtqhN1AgmdQ': 3.487491864227212,
#  'XYmTwXGeDhB5Ol3rpO7mmg': 3.4810838383785265,
#  '5Gj8twqkHxMunpNJLn5Hjw': 3.4744980396829277,
#  'ARPF656yM6oeEDSCnLhzIg': 3.4721202655403567,
#  'WPJl2RqaQrRoX34K8MGseg': 3.462072219107221,
#  'gIroxzbCiNsn9qIhpGDf0Q': 3.4536569558611485,
#  'QcW0360vpeEilCLBlKEiLw': 3.451440993119781,
#  'kpM-NegY__31O-XMEEesdg': 3.446995482317596,
#  'ZyGpQ9k1D0c4xd8k7I_RXw': 3.445320860209982,
#  'oZH3Ee7Yjk7u8B4Ed0oVOg': 3.4402268339768343,
#  'irwDkp2eMP2x-4MfunRt8g': 3.4402268339768343,
#  '2lcK3d4K7FU6O8wXdWzOmA': 3.432496745154034,
#  'I_eSnGmk5nDdsOL6Y4OAEg': 3.430911264917848,
#  'z2-Lr0Oe3EcI4e30CQgJiQ': 3.427671970781438,
#  'qXoJ_fLDtWNG6Cy1bB5cNg': 3.424147771732773,
#  'VtmG4MjDQ2rz6Jdi38gg-g': 3.421456304883011,
#  'YoYL__V3bUF4KluaJ8QO4A': 3.4103442419454075,
#  'WxqF4uNMcfTvJPRmxPKSaw': 3.409300175584604,
#  'PHceo653FqAeQHHrvvaMjA': 3.4030601902266056,
#  'tXQQ2_fbF7d4FKKODrJFCQ': 3.401354456413845,
#  'yA8iKH7GNFzA8jgyvjAg3g': 3.3921208975826502,
#  'iSJyMgmJ3DwG2uAywoCkPg': 3.3874365704384672,
#  '72XgsonBuUgIXrhTOrl4HA': 3.3814838490960613,
#  'DlPo03BheM-u-9UzzJu5pw': 3.371621621621622,
#  'Gr537ov5L1LKW6EvlyERGQ': 3.371621621621622,
#  '5rb2tq_AhxQuRYu_bh464g': 3.371621621621622,
#  '_cbRzxYBYsQq2MXuivztjw': 3.367102935235237,
#  'I4ZHa5S7vPMBauConLlbSg': 3.357301738838732,
#  'b--I9Ed6N5P9fwEb2qaiqg': 3.3572760800666224,
#  'W5k6WW_GALZJw_PaGr-mvQ': 3.3571189643971637,
#  '6Th0vVjtlAlTE0cu-xrCng': 3.3351269361224247,
#  'U0eUwTGWDBVdE67qVHYEjQ': 3.3149810210050594,
#  '5umxj22MPoFPskqPlY9pdA': 3.3051423560704434,
#  'YVJsWsHdiorH9xcoBV459Q': 3.2981237886552863,
#  't10X85k_m8RuAZZgoMzvXg': 3.2975463540619048,
#  '9jgZh0zCchGlMTKMh_ZV2Q': 3.2954275577864283,
#  'laz6mq3Jm505Lq5TfI_zjw': 3.291540653923713,
#  'EwkdJQAYqk9dDdmTmNYemg': 3.276701730451676,
#  'mW28NmePxX7pZv8lCv7v2Q': 3.2745332824011557,
#  'iZGktN1Zv0aX9yqTzZSfXA': 3.2708559075735493,
#  'Bg2Qcn3STmYHPCR8CT_Z2w': 3.268659778548006,
#  '-mP3F3srknwKJdJ5FqcX5Q': 3.2682438147662034,
#  'x5lN8HdgDVWXwoL9N7MDoQ': 3.267585249388212,
#  'ImbjRcr33wAm6o1ShWecpg': 3.2572544992629897,
#  'MRMtIcCJxCTLgZH4-uAQVw': 3.2568415134006954,
#  'qlsAl7z4NYuf7CVpF2BJcw': 3.2526489270255974,
#  '98wdsVO80rU_HmprfmzAFA': 3.25,
#  'x_TqELcRUk2csOWxqlyrzA': 3.243996273655383,
#  'EiVYrgOqG3Y9Ef9_ApZi4A': 3.24192544254864,
#  '1p5izA5Py5zN7CuNAxPkvw': 3.235907069794448,
#  'HCrnqF9Uh0QOoGbh5cyFIA': 3.2191640398657433,
#  '69Gyhl3O04NG6DGAoZ6t4Q': 3.2146182315701846,
#  'uFL4KroMu-dFRsSJrcFzVQ': 3.214176948021693,
#  'EOzsAFr7eF8D4C3a4ZQicw': 3.200026910074085,
#  'JOtv0NcBkvd9RO_D9cM3Qg': 3.1953024453024454,
#  '1sKRc9vFaZ_dLQGPE_P7Dg': 3.1782086967013496,
#  'SXbezCVeHdTMywIUA0pyAA': 3.1532832875284758,
#  'axGP6FXAZlBdmdN9juu1tQ': 3.1230932643563216,
#  '0nAFblolSC3TfbHDq8yjGQ': 3.121621621621622,
#  'aRmNacukkGh7n_geAbb7oA': 3.104605969139056,
#  'IYZ5TSguf72Pq-ZJzZu0WQ': 3.1,
#  '1ZmEH7_XLLaQS2TBtGqEWQ': 3.096705399825711,
#  'akRtfcCezswizRIaAqJ4fQ': 3.0883276405183455,
#  'BsLxCm_DMxCNVEPHoaj8hw': 3.0871565085917343,
#  'Youep7apWvvojHTPhmle7g': 3.0836834360153738,
#  '_2VNYA-7q7qjjCUqK1JeqQ': 3.0796424252997414,
#  'mEx2NJBepbnVSjZG6MqwJA': 3.076951625205928,
#  'b1KgvPR5WdhWwR1HRuSpVg': 3.0674895855871602,
#  '-pmqS-odJCmxOvWfRFAQ9Q': 3.0649017912935905,
#  'C_oejk3EzfsxP7-owQDkbQ': 3.064568902986511,
#  'JxxHisLgPWCxTN-0LOeZZw': 3.0519124232496067,
#  'UAYq5aheSkiNbzURc2Kjgw': 3.051205980238023,
#  'mY9tk1ZVMf9Zco9SaXMk6Q': 3.048654952629479,
#  'inifQjerB70iJb4ZyRBeqQ': 3.0363131595207946,
#  'sJ0EK29O_CxAdbDqn5b2zA': 3.033476476718596,
#  'agxkmEg9ziET-_CUlBrT2w': 3.032745858793362,
#  'I_RkxalxylAoseHesrgfJw': 3.029271766276236,
#  'axBhslRvyBiWlcX_Q0EKGQ': 3.028461488849107,
#  'ZiKbhlnVTZ0zZK9nvYwogg': 3.028286225515626,
#  'KbgfH1qMvnhMc7MSMZDs1Q': 3.0243243243243247,
#  'OvLn9_DDhHA0U5dYBT4RIA': 3.020662850270206,
#  'jAXFZLuccAbr7phf8A_Pwg': 3.0177884016841654,
#  'jRiTvHuF9_8JkQqywqa9zw': 3.011825708775855,
#  '_TF-f9u3kkC1qgvFTHLFxg': 3.01113633411871,
#  'mrQ60tOt_YGquGE2eIS7yw': 3.0111363341187096,
#  'OD88wvH-9LxM_Gz4oHOIDg': 3.0,
#  'wwnC1werIc0c27aH8D1IXg': 3.0,
#  'RZlmfM7BAUHRxRTn24Fx3w': 3.0,
#  '6nLb4ePbL2c7AeZDTckmxg': 2.9995473376025372,
#  'U1sdC4OHzPuLpl0ZY3YcPw': 2.998457639170203,
#  '_v7lMUtdd6WlgKUEBLA_VA': 2.9851952244784368,
#  'pMMFdnnEHsfoDm558mnl-w': 2.9848215734482384,
#  'J8klQB6PHeR5vZpz6L0S9w': 2.9662449021057244,
#  'jCacle289y_krOVMwTnEVQ': 2.964518545275139,
#  'VCxWnqcVP8WQkaSNDO0eEQ': 2.964518545275139,
#  'FKkQcB7a5vmTcAy36OYavQ': 2.959430727940239,
#  'hIXvV3d2cJ_N249RZo8e8g': 2.9424819720629283,
#  'UW4eSELXqFtg1X2C_aI1nA': 2.925735412807775,
#  'Z8MOONLTgDUxytU0w10Z4A': 2.921363181655095,
#  'aP8h2g80kZvPxo_1g3jAcw': 2.9144144144144146,
#  '47me-6Zme7RYR0zEonfaHg': 2.9144144144144146,
#  '6dDrLNa3_fx9E4lfKHtuig': 2.9144144144144146,
#  'ZTg8adZipR3QDoJmFZZqJw': 2.9144144144144146,
#  'CAALCmefoLQtDvLEER4_6Q': 2.885924326472126,
#  'fPDBfZ4v49OBbTk-Yd41yA': 2.874100182706233,
#  'JsFTgZEGe3xuTMdJQgx2Eg': 2.871984728012981,
#  'mbXXzrpkAw42CN3fb1-IZg': 2.85,
#  'akPPfcsTD6JmIEMEC8ByYQ': 2.848307334163188,
#  'CxN3Qxn_VCNEo9qa7FG-PA': 2.8312976787697153,
#  'z58nyUVyDV-vC7nXFfvR5g': 2.814828124123802,
#  'F82Vs1GQoPbRISBIpWIHMw': 2.809475318283383,
#  'IbEIEM16lqKlA4uiLt6Rew': 2.8083084594564274,
#  'SsEGTUufq5PvY9fIP2PSWQ': 2.8080316696024727,
#  'xnki9gbekoPntcxZhGx1nw': 2.804811556560832,
#  'VV5QvID1xPwmyYXW6aCTSQ': 2.7882882882882885,
#  'pRNz6EPc6ekD1lTxRZ3I4A': 2.746621621621622,
#  'jkDmcMpYWggYp5Ue4Nh-Dg': 2.731026966810298,
#  'XiuPTASXO1gyc8N2nwv_nQ': 2.7199999999999998,
#  'eHBefyiDT7-mjXcSrD1bYw': 2.7066441441441444,
#  'fDagCaRJU-KJK80jrbet6g': 2.7025525237777392,
#  'QaL-P_ijg0-MMfu1SGt47A': 2.6978665435130256,
#  'bzdb1jJ1j8Qn_RVHY97FnA': 2.689005179933711,
#  'v4WFgb4_rxCyfX1aG6eCZw': 2.664951481553526,
#  'KR2kRmHnRCaNzOUEGoB25w': 2.6605188844967858,
#  '9rywK-snede1djxYG4G9cA': 2.658611344970349,
#  'yG9SpxEQVIhk6e1o3jbSKg': 2.621621621621622,
#  '4wpeWu0lCR_eEdGiyZB9rg': 2.6106127525544984,
#  'XJ_iY07rHMqG3okVbDX-Lw': 2.5256576788983196,
#  '6Ko0igIzIFQgA3ejrXC3VQ': 2.5191441441441444,
#  'z_LKBi-nZz6FrQUu5ZTa7Q': 2.5,
#  'b7of9cI6NJ4a81BG8AnsKw': 2.499700971508456,
#  'SjPdKGRkhN9PwoA3YXUvDw': 2.4318074755891956,
#  'kTe4nTTPZb6SODnxs1QXDg': 2.4300451257241322,
#  'tAKHzOWCKcafcL5HiMqmOQ': 2.4298596139883935,
#  '1_yXNlfbGSn3pGjzNB99Yw': 2.4083734024198735,
#  'wD5mkyaBzyBMRbfpcAFUVQ': 2.4,
#  'H1xnw6h6K7jP4lQfvI-jLg': 2.4,
#  '_4Tus-IHFA4ErdNg32yvBQ': 2.3399023505395813,
#  '39nJBipHiWpGzRUTtDCzFA': 2.1722529080530455,
#  'FRgfSo84xbsMTISY39yecQ': 2.1361409146134154,
#  'MWcN6qLWTfRJqLySxwJNqQ': 2.0870910199403743,
#  'Bu8PfNwuML9UzTs34KhFuQ': 2.0542714484714524,
#  'WPeXqptw3n0XE0_N7ZTO2Q': 2.0542714484714524,
#  '-lAV1uegafxCjGE306kBYQ': 1.9651387809677932,
#  'pslcI7Kpiaq642v-kl0kVg': 1.914530848595661,
#  '0I0yATfnNQJB-A-IPGgqDA': 1.620840326174916,
#  'uk8pcPjJjwo7C2CYfGagXg': 1.5999999999999999,
#  'Dg58sciL12ezZbkimrGUJg': 1.593859873924666,
#  'MlIQON0U5-nFSiVez2mT4Q': 1.5,
#  '_W0s1el1dQaXy7ymZ5PdPQ': 1.0,
#  'sMuDjn2tk_-n7S1cyGhtjQ': 1.0,
#  'paN928wuyEHzxw7Zn5_snw': 1.0,
#  'uXCPUES8-cafSN_4oALhOQ': 1.0,
#  'U5-jFBtvoxdQ0vrxeg3jvw': 1.0,
#  'VZKWW2zQbk-rxwpAcque8w': 0,
#  'pIBX_IBixagX-2AzFPl77g': 0,
#  'zq4i9ZtLebbvyWjKXec3NQ': 0,
#  'LwhSCUUNP7b_9N9ZGY895Q': 0,
#  'z71IqTCbQW7uzw2H2T1QrA': 0,
#  'BpVflHvjyL05dgWVWkXW9w': 0,
#  'cbjF6szaq2orE0BplGAKEA': 0,
#  'kskhznHQtJFmNw6BQD2KMQ': 0,
#  '-oi8V6CcxMT4pUcs1XmLEg': 0,
#  'TyHWfpdHWdnny8q8THofPA': 0,
#  '_j7ea4fDZmaUJGBTnnhP-A': 0,
#  'YP_eIAjpq2qzmnh48u_VVw': 0,
#  'RYvq0j_olJletK6gA-VdlQ': 0,
#  '8GKs0ZQTD9m1ITausv4FFA': 0,
#  '2ZnybrfhN8UFiMXtEamf0g': 0,
#  'n_--xb4wLuP6wzuZswJR6A': 0,
#  '8fDwicUJDHMr1oHUdY2LDQ': 0,
#  'rIXjH2IJnf5oppXvKLHD_w': 0,
#  'BBFkGP5KfOY5Y5y3RKISOA': 0,
#  'pDn3TAjVcY7TqtZD9YI38A': 0,
#  'sgp8YKTZtpsjCoZlQGZndg': 0,
#  'L3F7AnYRNF80JF55swS7ZQ': 0,
#  'piHqTyHSdeDuqpHM8dyDIg': 0,
#  '13PSWBZyaP89VaQCRerwQA': 0,
#  '7AOHKdEvUrpcx0kba_tQmw': 0,
#  'C1b4cTY1wysxgBqtv634MA': 0,
#  'RjpB0Zjaw0JbkBnOLDcUBw': 0,
#  'qFrCX-bXxw_7Kmy1Pb8wrw': 0,
#  'zPvaMKlV8KKEUwtN9bWWRQ': 0,
#  'a-dy79pezdj0bZeeDxdsnA': 0,
#  'fe_6rflZHbNiYQk3XTjdxw': 0,
#  'uiZQ9XqZ8cTbHtmkClp3Yw': 0,
#  '10yMh47KzS5Y3-upBuP2vA': 0,
#  '1AYsT9NunR_UXY26rVIjXw': 0,
#  'WF09vP1_hsxXYNoOaJrzOQ': 0,
#  'C4d0yUIz0wlLeWRnOIlErg': 0,
#  'blrovAH_SSlyXYGqsvmY8Q': 0,
#  'zF-rCRzv3tTDbO5oqT5lkw': 0,
#  'K2wi5V-Ab9aYIGcl7AXCRQ': 0,
#  '4u2C1mQQMqdWm32H998Zng': 0,
#  'lGepEeaqkMd6H_RJOeM93g': 0,
#  'Bk3yUv6mJqSCTbyFNbgeSw': 0,
#  '7zkvJg3nKMJU3FyJN3LDVA': 0,
#  '1NNBpiQ3rUT-7T8ch45SVA': 0,
#  '0VJ8tBxOpD2OxuioVjaAxA': 0,
#  'L9OO1eLDyqW8ALDaA2374A': 0,
#  'ZgP065QrIyre5WBUEqWtcg': 0,
#  '6yX87q3kmD1-5pX_ykj7AA': 0,
#  'vGoiB01Qj3D53yq0ZZJv1g': 0,
#  'NR5JHayuJOH34lnwSpr3Dg': 0,
#  'Bvq8vCNt556aoYGA5UrVeA': 0,
#  'SRevXU9q4n2CVMRzjPOw7g': 0,
#  '132kYoXPHORw_FgxvQfyGQ': 0,
#  'R-jNIcEg08k7IBh7nF5how': 0,
#  '2sTYUvBkn9qvQAH3AG00Dw': 0,
#  'kBWtmfQG7Y1e_BwN68y_kg': 0,
#  'RRWJcL-hUI1GPP5LAFtOXw': 0,
#  '6CSyxrLEh80pfex4FESQrQ': 0,
#  'YmDngTc_7lLA1jGcvq7odw': 0,
#  'uisfAopUaCje3w5_bv4nrQ': 0,
#  't_P8ytCOuxG-0uqscG9o5w': 0,
#  'tksWRZpkh-IClEM4IDd24A': 0,
#  'Tvg8i6x2DOqC1KDi3w4KBw': 0,
#  '973nneT7EUq8p2JU5bQjsQ': 0,
#  'dvr_UuNoU13N9E1SjRcHsw': 0,
#  'r0DureDzsHpzs_VZem5k7g': 0,
#  'U_SENiY-YFsEz4eJBOxscQ': 0,
#  'jE-_KmwyAIGlLNZitn--CA': 0,
#  '2zXOtI2YcBYOoSjeUp4fbQ': 0,
#  'OeCiSbRsYrwJkKlfyKhZng': 0,
#  'BpZ3v6T8PoSRRF2UCj7y_A': 0,
#  'BKtpv_Fx7Z578bkG-voKKA': 0,
#  'eUxY9-SyEvCaAJZSNTHw5Q': 0,
#  '7TYkVIjlI-NfVgdeSYhorA': 0,
#  '4pjJB_AHL43iS1OOp0CCFg': 0,
#  'KKpgguQp1oF_HzKGfAiaew': 0,
#  'b6xk-WBLVbulYf723eDT-g': 0,
#  'My2pi-5HgQVwdNbtRSzcXQ': 0,
#  'wTNWq7jrCZD1q2hSjUtTXg': 0,
#  'JN5JuLfr7mPhJuCpkXt2vg': 0,
#  'xs2HifwTAQcmhnBR_shHrw': 0,
#  '7FpIAmZsiQ8PpdBzpgEV9A': 0,
#  'pb4TraanL3CaSTXIrfJp7A': 0,
#  '5MWWP4Kpmw0e8d2ib9G7Kg': 0,
#  'M8yQIYwL5j1OJNLOLw7Q0w': 0,
#  'ux6Bn9-efIwP3InXo3f8jg': 0,
#  'eigkQ_PuRON8Se265NqQDQ': 0,
#  'TyeLUMLGRcp3mtBlkS5jpA': 0,
#  'PzuyoHj3-VrYK7N8ZestNA': 0,
#  'AAjxCL5EXipbA9ScTNpSMg': 0,
#  'f510nTuxAMc0AQh-h4Q3pA': 0,
#  'XlQ8KKrYzfJjgPuEGB81Aw': 0,
#  'C9j5ff4NwARq5vUzMa94pg': 0,
#  'dVvij7VRh55dISu02I0IGw': 0,
#  'SIdA020Wagb_3zeed7d7Cg': 0,
#  'qt_eoA_mkuv2XJefW79fhg': 0,
#  'a8_n_O5Hk2mWkNfz47NfMA': 0,
#  'czxvydFY73S95HZqOOK2uQ': 0,
#  '2A-C3WBhXen91t-TXByC6w': 0,
#  'TwSBs6QfEJxAxLRJ5RM-pQ': 0,
#  'SyPDvXyR66buF_K0BEiUDw': 0,
#  'zKyXbR3n4D74IS9ppg4YyA': 0,
#  'xphYIW9zqCr_3CfcAhFppg': 0,
#  'mpl401TorCGAkwKCCga6NQ': 0,
#  'spjaRNFn9Lmh4petKBuf5g': 0,
#  'KK9ohx-yj-wLojdnOX3I3w': 0,
#  'Om8Nlhf8g7yxgqxZEmyeaw': 0,
#  'Kpj2Avhn5JW77QSNnzFFBA': 0,
#  'tEe_cAOM8kdkXl_7GqEMkg': 0}
